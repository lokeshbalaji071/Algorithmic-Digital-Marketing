# %%
import os
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('D:\\Information System\\ADM\\Project\\apple_reviews.csv')
df
# Out:
#                     category  rating                              product  \
# 0      Mobiles & Accessories       1  New Apple iPhone 11 (64GB) - Purple
# 1      Mobiles & Accessories       1  New Apple iPhone 11 (64GB) - Purple
# 2      Mobiles & Accessories       1  New Apple iPhone 11 (64GB) - Purple
# 3      Mobiles & Accessories       1  New Apple iPhone 11 (64GB) - Purple
# 4      Mobiles & Accessories       1  New Apple iPhone 11 (64GB) - Purple
# ...                      ...     ...                                  ...
# 19679  Mobiles & Accessories       5        Apple iPhone 7 (32GB) - Black
# 19680  Mobiles & Accessories       5        Apple iPhone 7 (32GB) - Black
# 19681  Mobiles & Accessories       5        Apple iPhone 7 (32GB) - Black
# 19682  Mobiles & Accessories       5        Apple iPhone 7 (32GB) - Black
# 19683  Mobiles & Accessories       5        Apple iPhone 7 (32GB) - Black
#
#       helpful_count           crawled_at                 sub_category  \
# 0               356  2021-01-26 13:54:03  Smartphones & Basic Mobiles
# 1               363  2021-01-26 13:54:03  Smartphones & Basic Mobiles
# 2               239  2021-01-26 13:54:03  Smartphones & Basic Mobiles
# 3               277  2021-01-26 13:54:03  Smartphones & Basic Mobiles
# 4               191  2021-01-26 13:54:03  Smartphones & Basic Mobiles
# ...             ...                  ...                          ...
# 19679             2  2021-01-26 13:14:06  Smartphones & Basic Mobiles
# 19680             0  2021-01-26 13:14:06  Smartphones & Basic Mobiles
# 19681             0  2021-01-26 13:14:06  Smartphones & Basic Mobiles
# 19682             4  2021-01-26 13:14:06  Smartphones & Basic Mobiles
# 19683             0  2021-01-26 13:14:06  Smartphones & Basic Mobiles
#
#              asin review_country  \
# 0      B08L8CHS2X          India
# 1      B08L8CHS2X          India
# 2      B08L8CHS2X          India
# 3      B08L8CHS2X          India
# 4      B08L8CHS2X          India
# ...           ...            ...
# 19679  B01LZKSVRB          India
# 19680  B01LZKSVRB          India
# 19681  B01LZKSVRB          India
# 19682  B01LZKSVRB          India
# 19683  B01LZKSVRB          India
#
#                                          raw_description  \
# 0      <span class="a-size-base review-text review-te...
# 1      <span class="a-size-base review-text review-te...
# 2      <span class="a-size-base review-text review-te...
# 3      <span class="a-size-base review-text review-te...
# 4      <span class="a-size-base review-text review-te...
# ...                                                  ...
# 19679  <span class="a-size-base review-text review-te...
# 19680  <span class="a-size-base review-text review-te...
# 19681  <span class="a-size-base review-text review-te...
# 19682  <span class="a-size-base review-text review-te...
# 19683  <span class="a-size-base review-text review-te...
#
#                                              description     profile_name  \
# 0      \n\n  The phone seems to be owned by some shiv...  Amazon Customer
# 1      \n\n  Its my first iphone and now I’m feeling ...     Bhawna juyal
# 2      \n\n  I found this black spot while doing set ...          Vinayak
# 3      \n\n  Samsung s10 is much better than iphone 1...     Shipra Goyal
# 4      \n\n  hiI had purchased this phone in first we...      gaurav garg
# ...                                                  ...              ...
# 19679  \n\n  its a awsum phone but they said that the...              Sid
# 19680  \n\n  I purchased this when there was a deal f...      Ashwin Mani
# 19681                            \n\n  User friendly\n\n  Rincy Jesudasan
# 19682  \n\n  The iPhone 7 and 7 Plus are deeply unusu...       Adit raval
# 19683  \n\n  Have been using this device for more tha...     Jobin Thomas
#
#                reviewed_at                                   _id  \
# 0      2020-06-10 00:00:00  f7030d10-c987-536b-a356-f642cb1ec5e3
# 1      2019-10-10 00:00:00  775c9997-8c2c-5dda-9faf-0f0e29ac9cb0
# 2      2020-06-06 00:00:00  089a10aa-ef92-577c-93f7-fd85e26f6bf0
# 3      2019-10-23 00:00:00  217a69c8-f3d6-58b0-9ec0-8a1e3514e24e
# 4      2020-06-24 00:00:00  5e2e9ea9-a32d-51fe-bd7b-f0ebe5749ebd
# ...                    ...                                   ...
# 19679  2017-05-05 00:00:00  8a60486d-1e5e-5178-aef4-5e3e33d787fa
# 19680  2018-02-10 00:00:00  2c476d59-47dc-56f9-b814-1ee5d1cd8912
# 19681  2020-07-15 00:00:00  703678e9-de3f-5347-8818-adedc76b8a6d
# 19682  2017-05-27 00:00:00  9cb3d015-a75e-52d7-8fb4-c83fe23b9b15
# 19683  2019-05-06 00:00:00  1f9d06ac-a83a-5dfa-888c-d73afbd74547
#
#        average_rating product_company  \
# 0                 4.5           Apple
# 1                 4.5           Apple
# 2                 4.5           Apple
# 3                 4.5           Apple
# 4                 4.5           Apple
# ...               ...             ...
# 19679             4.1           Apple
# 19680             4.1           Apple
# 19681             4.1           Apple
# 19682             4.1           Apple
# 19683             4.1           Apple
#
#                                             review_title  review_uniq_id  \
# 0                                     Second hand device   RCNKLUGAMJBPH
# 1                                          Heating issue  R1HWMMIJ21WTZR
# 2                     Black spot found on the new phone.  R3FZWAU9I8B7Q5
# 3                      Samsung s10 is better than iphone  R386FDLMAZDUPG
# 4                                        Defective model   RXAOS1IG04N09
# ...                                                  ...             ...
# 19679  nice phone..price is high compare to other phones  R2F9GDPV8JERN0
# 19680                                        Great phone  R1C48E7FWYVCTD
# 19681                                       Nice product  R1XLRWRUS2ANYR
# 19682  They are full of aggressive breaks from conven...   RSJ6EYV1EPV8A
# 19683                                     iOS is awesome   R34RBD5QOQ9L4
#
#                                                   images  verified_purchase  \
# 0                                                     []               True
# 1                                                     []               True
# 2      ['https://images-na.ssl-images-amazon.com/imag...               True
# 3                                                     []               True
# 4                                                     []               True
# ...                                                  ...                ...
# 19679                                                 []               True
# 19680                                                 []              False
# 19681                                                 []              False
# 19682                                                 []              False
# 19683  ['https://images-na.ssl-images-amazon.com/imag...              False
#
#        total_comments
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0
# ...               ...
# 19679               0
# 19680               0
# 19681               0
# 19682               0
# 19683               0
#
# [19684 rows x 20 columns]

# %%
df['description']
# Out:
# 0        \n\n  The phone seems to be owned by some shiv...
# 1        \n\n  Its my first iphone and now I’m feeling ...
# 2        \n\n  I found this black spot while doing set ...
# 3        \n\n  Samsung s10 is much better than iphone 1...
# 4        \n\n  hiI had purchased this phone in first we...
#                                ...
# 19679    \n\n  its a awsum phone but they said that the...
# 19680    \n\n  I purchased this when there was a deal f...
# 19681                              \n\n  User friendly\n\n
# 19682    \n\n  The iPhone 7 and 7 Plus are deeply unusu...
# 19683    \n\n  Have been using this device for more tha...
# Name: description, Length: 19684, dtype: object

# %%
df['description'] = df['description'].str.rstrip('\r\r\n')
df['description'] = df['description'].str.lstrip('\r\r\n')

# %%
df['description']
# Out:
# 0          The phone seems to be owned by some shivang ...
# 1          Its my first iphone and now I’m feeling like...
# 2          I found this black spot while doing set up. ...
# 3                Samsung s10 is much better than iphone 11
# 4          hiI had purchased this phone in first week o...
#                                ...
# 19679      its a awsum phone but they said that the pro...
# 19680      I purchased this when there was a deal for 3...
# 19681                                        User friendly
# 19682      The iPhone 7 and 7 Plus are deeply unusual d...
# 19683      Have been using this device for more than 7 ...
# Name: description, Length: 19684, dtype: object

# %%
df
# Out:
#                     category  rating                              product  \
# 0      Mobiles & Accessories       1  New Apple iPhone 11 (64GB) - Purple
# 1      Mobiles & Accessories       1  New Apple iPhone 11 (64GB) - Purple
# 2      Mobiles & Accessories       1  New Apple iPhone 11 (64GB) - Purple
# 3      Mobiles & Accessories       1  New Apple iPhone 11 (64GB) - Purple
# 4      Mobiles & Accessories       1  New Apple iPhone 11 (64GB) - Purple
# ...                      ...     ...                                  ...
# 19679  Mobiles & Accessories       5        Apple iPhone 7 (32GB) - Black
# 19680  Mobiles & Accessories       5        Apple iPhone 7 (32GB) - Black
# 19681  Mobiles & Accessories       5        Apple iPhone 7 (32GB) - Black
# 19682  Mobiles & Accessories       5        Apple iPhone 7 (32GB) - Black
# 19683  Mobiles & Accessories       5        Apple iPhone 7 (32GB) - Black
#
#       helpful_count           crawled_at                 sub_category  \
# 0               356  2021-01-26 13:54:03  Smartphones & Basic Mobiles
# 1               363  2021-01-26 13:54:03  Smartphones & Basic Mobiles
# 2               239  2021-01-26 13:54:03  Smartphones & Basic Mobiles
# 3               277  2021-01-26 13:54:03  Smartphones & Basic Mobiles
# 4               191  2021-01-26 13:54:03  Smartphones & Basic Mobiles
# ...             ...                  ...                          ...
# 19679             2  2021-01-26 13:14:06  Smartphones & Basic Mobiles
# 19680             0  2021-01-26 13:14:06  Smartphones & Basic Mobiles
# 19681             0  2021-01-26 13:14:06  Smartphones & Basic Mobiles
# 19682             4  2021-01-26 13:14:06  Smartphones & Basic Mobiles
# 19683             0  2021-01-26 13:14:06  Smartphones & Basic Mobiles
#
#              asin review_country  \
# 0      B08L8CHS2X          India
# 1      B08L8CHS2X          India
# 2      B08L8CHS2X          India
# 3      B08L8CHS2X          India
# 4      B08L8CHS2X          India
# ...           ...            ...
# 19679  B01LZKSVRB          India
# 19680  B01LZKSVRB          India
# 19681  B01LZKSVRB          India
# 19682  B01LZKSVRB          India
# 19683  B01LZKSVRB          India
#
#                                          raw_description  \
# 0      <span class="a-size-base review-text review-te...
# 1      <span class="a-size-base review-text review-te...
# 2      <span class="a-size-base review-text review-te...
# 3      <span class="a-size-base review-text review-te...
# 4      <span class="a-size-base review-text review-te...
# ...                                                  ...
# 19679  <span class="a-size-base review-text review-te...
# 19680  <span class="a-size-base review-text review-te...
# 19681  <span class="a-size-base review-text review-te...
# 19682  <span class="a-size-base review-text review-te...
# 19683  <span class="a-size-base review-text review-te...
#
#                                              description     profile_name  \
# 0        The phone seems to be owned by some shivang ...  Amazon Customer
# 1        Its my first iphone and now I’m feeling like...     Bhawna juyal
# 2        I found this black spot while doing set up. ...          Vinayak
# 3              Samsung s10 is much better than iphone 11     Shipra Goyal
# 4        hiI had purchased this phone in first week o...      gaurav garg
# ...                                                  ...              ...
# 19679    its a awsum phone but they said that the pro...              Sid
# 19680    I purchased this when there was a deal for 3...      Ashwin Mani
# 19681                                      User friendly  Rincy Jesudasan
# 19682    The iPhone 7 and 7 Plus are deeply unusual d...       Adit raval
# 19683    Have been using this device for more than 7 ...     Jobin Thomas
#
#                reviewed_at                                   _id  \
# 0      2020-06-10 00:00:00  f7030d10-c987-536b-a356-f642cb1ec5e3
# 1      2019-10-10 00:00:00  775c9997-8c2c-5dda-9faf-0f0e29ac9cb0
# 2      2020-06-06 00:00:00  089a10aa-ef92-577c-93f7-fd85e26f6bf0
# 3      2019-10-23 00:00:00  217a69c8-f3d6-58b0-9ec0-8a1e3514e24e
# 4      2020-06-24 00:00:00  5e2e9ea9-a32d-51fe-bd7b-f0ebe5749ebd
# ...                    ...                                   ...
# 19679  2017-05-05 00:00:00  8a60486d-1e5e-5178-aef4-5e3e33d787fa
# 19680  2018-02-10 00:00:00  2c476d59-47dc-56f9-b814-1ee5d1cd8912
# 19681  2020-07-15 00:00:00  703678e9-de3f-5347-8818-adedc76b8a6d
# 19682  2017-05-27 00:00:00  9cb3d015-a75e-52d7-8fb4-c83fe23b9b15
# 19683  2019-05-06 00:00:00  1f9d06ac-a83a-5dfa-888c-d73afbd74547
#
#        average_rating product_company  \
# 0                 4.5           Apple
# 1                 4.5           Apple
# 2                 4.5           Apple
# 3                 4.5           Apple
# 4                 4.5           Apple
# ...               ...             ...
# 19679             4.1           Apple
# 19680             4.1           Apple
# 19681             4.1           Apple
# 19682             4.1           Apple
# 19683             4.1           Apple
#
#                                             review_title  review_uniq_id  \
# 0                                     Second hand device   RCNKLUGAMJBPH
# 1                                          Heating issue  R1HWMMIJ21WTZR
# 2                     Black spot found on the new phone.  R3FZWAU9I8B7Q5
# 3                      Samsung s10 is better than iphone  R386FDLMAZDUPG
# 4                                        Defective model   RXAOS1IG04N09
# ...                                                  ...             ...
# 19679  nice phone..price is high compare to other phones  R2F9GDPV8JERN0
# 19680                                        Great phone  R1C48E7FWYVCTD
# 19681                                       Nice product  R1XLRWRUS2ANYR
# 19682  They are full of aggressive breaks from conven...   RSJ6EYV1EPV8A
# 19683                                     iOS is awesome   R34RBD5QOQ9L4
#
#                                                   images  verified_purchase  \
# 0                                                     []               True
# 1                                                     []               True
# 2      ['https://images-na.ssl-images-amazon.com/imag...               True
# 3                                                     []               True
# 4                                                     []               True
# ...                                                  ...                ...
# 19679                                                 []               True
# 19680                                                 []              False
# 19681                                                 []              False
# 19682                                                 []              False
# 19683  ['https://images-na.ssl-images-amazon.com/imag...              False
#
#        total_comments
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0
# ...               ...
# 19679               0
# 19680               0
# 19681               0
# 19682               0
# 19683               0
#
# [19684 rows x 20 columns]

# %%
review_df = pd.DataFrame.from_records(data=df, columns = ['product','description'])
print(review_df['description'])
# Out:
# 0          The phone seems to be owned by some shivang ...
# 1          Its my first iphone and now I’m feeling like...
# 2          I found this black spot while doing set up. ...
# 3                Samsung s10 is much better than iphone 11
# 4          hiI had purchased this phone in first week o...
#                                ...
# 19679      its a awsum phone but they said that the pro...
# 19680      I purchased this when there was a deal for 3...
# 19681                                        User friendly
# 19682      The iPhone 7 and 7 Plus are deeply unusual d...
# 19683      Have been using this device for more than 7 ...
# Name: description, Length: 19684, dtype: object

# %%
review_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19684 entries, 0 to 19683
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   product      19684 non-null  object
#  1   description  19678 non-null  object
# dtypes: object(2)
# memory usage: 307.7+ KB

# %%
review_df['description'] = review_df['description'].astype('str')

# %%
import re
"Remove Numbers"
review_df['review_remove_num'] = review_df['description'].apply(lambda x:re.sub("[0-9]", "", x))
review_df.head()
# Out:
#                                product  \
# 0  New Apple iPhone 11 (64GB) - Purple
# 1  New Apple iPhone 11 (64GB) - Purple
# 2  New Apple iPhone 11 (64GB) - Purple
# 3  New Apple iPhone 11 (64GB) - Purple
# 4  New Apple iPhone 11 (64GB) - Purple
#
#                                          description  \
# 0    The phone seems to be owned by some shivang ...
# 1    Its my first iphone and now I’m feeling like...
# 2    I found this black spot while doing set up. ...
# 3          Samsung s10 is much better than iphone 11
# 4    hiI had purchased this phone in first week o...
#
#                                    review_remove_num
# 0    The phone seems to be owned by some shivang ...
# 1    Its my first iphone and now I’m feeling like...
# 2    I found this black spot while doing set up. ...
# 3              Samsung s is much better than iphone
# 4    hiI had purchased this phone in first week o...

# %%
"Change to lower case"
review_df['review_lower'] = review_df['description'].apply(lambda x: x.lower())
review_df.head()
# Out:
#                                product  \
# 0  New Apple iPhone 11 (64GB) - Purple
# 1  New Apple iPhone 11 (64GB) - Purple
# 2  New Apple iPhone 11 (64GB) - Purple
# 3  New Apple iPhone 11 (64GB) - Purple
# 4  New Apple iPhone 11 (64GB) - Purple
#
#                                          description  \
# 0    The phone seems to be owned by some shivang ...
# 1    Its my first iphone and now I’m feeling like...
# 2    I found this black spot while doing set up. ...
# 3          Samsung s10 is much better than iphone 11
# 4    hiI had purchased this phone in first week o...
#
#                                    review_remove_num  \
# 0    The phone seems to be owned by some shivang ...
# 1    Its my first iphone and now I’m feeling like...
# 2    I found this black spot while doing set up. ...
# 3              Samsung s is much better than iphone
# 4    hiI had purchased this phone in first week o...
#
#                                         review_lower
# 0    the phone seems to be owned by some shivang ...
# 1    its my first iphone and now i’m feeling like...
# 2    i found this black spot while doing set up. ...
# 3          samsung s10 is much better than iphone 11
# 4    hii had purchased this phone in first week o...

# %%
"Count number of stop words"
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')
stop_words += ["he's", "i'm", "can't", "i've"]
stop_words += ['a', 'about', 'above', 'across', 'after', 'afterwards']
stop_words += ['again', 'against', 'all', 'almost', 'alone', 'along']
stop_words += ['this', 'is', 'your']
review_df['number of stop words'] = review_df['description'].apply(lambda x: len([wd for wd in x if wd in stop_words]))
review_df.head()
print(stop_words)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\tharo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't", "he's", "i'm", "can't", "i've", 'a', 'about', 'above', 'across', 'after', 'afterwards', 'again', 'against', 'all', 'almost', 'alone', 'along', 'this', 'is', 'your']

# %%
"Remove stopwprds"
review_df['review_without_stopwords'] = review_df['review_lower'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop_words)]))
review_df.head()
# Out:
#                                product  \
# 0  New Apple iPhone 11 (64GB) - Purple
# 1  New Apple iPhone 11 (64GB) - Purple
# 2  New Apple iPhone 11 (64GB) - Purple
# 3  New Apple iPhone 11 (64GB) - Purple
# 4  New Apple iPhone 11 (64GB) - Purple
#
#                                          description  \
# 0    The phone seems to be owned by some shivang ...
# 1    Its my first iphone and now I’m feeling like...
# 2    I found this black spot while doing set up. ...
# 3          Samsung s10 is much better than iphone 11
# 4    hiI had purchased this phone in first week o...
#
#                                    review_remove_num  \
# 0    The phone seems to be owned by some shivang ...
# 1    Its my first iphone and now I’m feeling like...
# 2    I found this black spot while doing set up. ...
# 3              Samsung s is much better than iphone
# 4    hiI had purchased this phone in first week o...
#
#                                         review_lower  number of stop words  \
# 0    the phone seems to be owned by some shivang ...                   162
# 1    its my first iphone and now i’m feeling like...                    36
# 2    i found this black spot while doing set up. ...                    46
# 3          samsung s10 is much better than iphone 11                    13
# 4    hii had purchased this phone in first week o...                   177
#
#                             review_without_stopwords
# 0  phone seems owned shivang gupta earlier...he d...
# 1  first iphone i’m feeling like i’ve wasted mone...
# 2  found black spot set up. given defective piece...
# 3                  samsung s10 much better iphone 11
# 4  hii purchased phone first week june 2020 trust...

# %%
"Word Stemming"
import re
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
words = stopwords.words("english")
review_df['review_stem'] = review_df['review_without_stopwords'].apply(lambda x: " ".join([stemmer.stem(i) for i in re.sub("[^a-zA-Z]", " ", x).split() if i not in stop_words]).lower())
review_df.head()
# Out:
#                                product  \
# 0  New Apple iPhone 11 (64GB) - Purple
# 1  New Apple iPhone 11 (64GB) - Purple
# 2  New Apple iPhone 11 (64GB) - Purple
# 3  New Apple iPhone 11 (64GB) - Purple
# 4  New Apple iPhone 11 (64GB) - Purple
#
#                                          description  \
# 0    The phone seems to be owned by some shivang ...
# 1    Its my first iphone and now I’m feeling like...
# 2    I found this black spot while doing set up. ...
# 3          Samsung s10 is much better than iphone 11
# 4    hiI had purchased this phone in first week o...
#
#                                    review_remove_num  \
# 0    The phone seems to be owned by some shivang ...
# 1    Its my first iphone and now I’m feeling like...
# 2    I found this black spot while doing set up. ...
# 3              Samsung s is much better than iphone
# 4    hiI had purchased this phone in first week o...
#
#                                         review_lower  number of stop words  \
# 0    the phone seems to be owned by some shivang ...                   162
# 1    its my first iphone and now i’m feeling like...                    36
# 2    i found this black spot while doing set up. ...                    46
# 3          samsung s10 is much better than iphone 11                    13
# 4    hii had purchased this phone in first week o...                   177
#
#                             review_without_stopwords  \
# 0  phone seems owned shivang gupta earlier...he d...
# 1  first iphone i’m feeling like i’ve wasted mone...
# 2  found black spot set up. given defective piece...
# 3                  samsung s10 much better iphone 11
# 4  hii purchased phone first week june 2020 trust...
#
#                                          review_stem
# 0  phone seem own shivang gupta earlier detail fi...
# 1     first iphon feel like wast money coz heat issu
# 2  found black spot set given defect piec abl giv...
# 3                          samsung much better iphon
# 4  hii purchas phone first week june trust amazon...

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
from nltk.tag import pos_tag
from nltk.corpus import wordnet as wn
from nltk.stem.wordnet import WordNetLemmatizer
from nltk import word_tokenize, pos_tag
from collections import defaultdict
import string
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\tharo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\tharo\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\tharo\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
def lemmatize_sentence(data):
    data = ''.join([i for i in data if i not in string.punctuation or i == '\''])
    tag_map = defaultdict(lambda : wn.NOUN)
    tag_map['ADJ'] = wn.ADJ
    tag_map['VER'] = wn.VERB
    tag_map['ADV'] = wn.ADV
    tokens = data.split()
    lemmatized_sentence = []
    lemmatizer = WordNetLemmatizer()
    for token, tag in pos_tag(tokens):
      if '\'' in token:
        continue
      lemmatized_sentence.append(lemmatizer.lemmatize(token, tag_map[tag[0]]))   
    return ' '.join(lemmatized_sentence)

# %%
review_df['reviewLemmatized'] = review_df['review_without_stopwords'].apply(lambda x: lemmatize_sentence(x))
review_df.head()
# Out:
#                                product  \
# 0  New Apple iPhone 11 (64GB) - Purple
# 1  New Apple iPhone 11 (64GB) - Purple
# 2  New Apple iPhone 11 (64GB) - Purple
# 3  New Apple iPhone 11 (64GB) - Purple
# 4  New Apple iPhone 11 (64GB) - Purple
#
#                                          description  \
# 0    The phone seems to be owned by some shivang ...
# 1    Its my first iphone and now I’m feeling like...
# 2    I found this black spot while doing set up. ...
# 3          Samsung s10 is much better than iphone 11
# 4    hiI had purchased this phone in first week o...
#
#                                    review_remove_num  \
# 0    The phone seems to be owned by some shivang ...
# 1    Its my first iphone and now I’m feeling like...
# 2    I found this black spot while doing set up. ...
# 3              Samsung s is much better than iphone
# 4    hiI had purchased this phone in first week o...
#
#                                         review_lower  number of stop words  \
# 0    the phone seems to be owned by some shivang ...                   162
# 1    its my first iphone and now i’m feeling like...                    36
# 2    i found this black spot while doing set up. ...                    46
# 3          samsung s10 is much better than iphone 11                    13
# 4    hii had purchased this phone in first week o...                   177
#
#                             review_without_stopwords  \
# 0  phone seems owned shivang gupta earlier...he d...
# 1  first iphone i’m feeling like i’ve wasted mone...
# 2  found black spot set up. given defective piece...
# 3                  samsung s10 much better iphone 11
# 4  hii purchased phone first week june 2020 trust...
#
#                                          review_stem  \
# 0  phone seem own shivang gupta earlier detail fi...
# 1     first iphon feel like wast money coz heat issu
# 2  found black spot set given defect piec abl giv...
# 3                          samsung much better iphon
# 4  hii purchas phone first week june trust amazon...
#
#                                     reviewLemmatized
# 0  phone seems owned shivang gupta earlierhe deta...
# 1  first iphone i’m feeling like i’ve wasted mone...
# 2  found black spot set up given defective piece ...
# 3                  samsung s10 much better iphone 11
# 4  hii purchased phone first week june 2020 trust...

# %%
vocabulary = list(review_df['reviewLemmatized'])
print(vocabulary)
print(len(vocabulary))
# Out:
# ['phone seems owned shivang gupta earlierhe detail filled dishearting know esteemed company like apple amazon woul provide user second hand device need serious immediate attentionregardsdeputy directorbureau indian standardsministry consumer affair public distributionministry consumer affair', 'first iphone i’m feeling like i’ve wasted money coz heating issue', 'found black spot set up given defective piece able give replacement also next day purchase', 'samsung s10 much better iphone 11', 'hii purchased phone first week june 2020 trusting amazonbut phone defective failed update failed connect serversfinding solution used old version io hoping work finebut working fine everytime hang able worktoday putting charging blast battery since workingi exceeded return period perhaps 70 thousand gone drain', 'good charge mobilebody earth current shock today charger working don’t replace', 'pathetic amazon service buy online back camera problem show many green dot apple store little help amazon expected help waiting get resolved preferred pixel camera sigh', 'phone11 model black look like chinese phonei suggest purchase go model', 'worst phn boughtstarted heat badly first time switched moreover heat everytime switch ontried returning apple buy amazon', 'ordered 24 january 2020 already three issue bluetooth working phone getting hanged battery back low product defect 6 day purchased bad experience never thaught', 'received defective product exchange return also easy need contact apple get back amazon please think buying badly disappointed expect amazon wasted money', 'bought sale per offer caahback rs1250 credited amazon pay account called service centre many time initially used tell would credited next 48 hour waiting cashback several day got know service centre eligible cashback pathetic amazon', 'far good lot review related heating phone bit worried update io required par androidupdate using 3 month could say android o far better io apple need work lot thing would say apple give android phone developer know added io overall useless operating systemhope new release match androidthose using android thinking switching iphones please don’t even think it', 'received defective piece there’s option replace apple store 250kms away address', 'booked iphone 11 sale 16th october cash back offer amazon rs1250 clearly written cashback receive amazon pay within 3 working day shippingi got still cashback even calling customer care response got cash back amountthis really worst thing amazon cheating customer showing discountsoffersdeals', 'new iphone mobile purchased amazon getting heated using device minute also noted charge getting extra hotso please contact use urgently replace devise urgently refer delivery address contact number order', 'bought appario first time unsatified amazon particulary spending lot buck could expect bettery quality phone guy delivered defective product taken 100 plus photo could clearly see difference photo even competing iphone 6 samsung a50 sure apple branded product dupliacte product amazon please dont encourage type seller', 'buy all display worst display apple ever camera performance cheap', 'dear amazon supportcustomer carethis l write bring notice regarding extremely bad quality product support provided amazonto brief situation bought apple iphone11 amazon platform trust amazon great support team time around completely opposite situation receiving product 30102020 product discolored like damage immediately tried replace product option available app app would direct back link apple support website contact number several try final got apple support redirected apple store reaching apple store limited stringent work hour asked come next day next day informed issue need taken amazon onlyafter extremely tired entire long process great difficulty could connect amazon customer support customer support assured resolving issue asked wait 24 hour get callpost this already 40 hour yet receive call furthermore trying call number ...
# 19684

# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
import re
from nltk.stem import PorterStemmer
nltk.download('stopwords')
stop_words = stopwords.words('english')
stemmer = PorterStemmer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\tharo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# define a method for data cleaning
def dataClean(resource):
  review_df = pd.DataFrame.from_records(data=resource, columns = ['review', 'labels'])
  review_df['review_lower'] = review_df['review'].apply(lambda x: x.lower()) # change to lowercase
  review_df['review_without_stopwords'] = review_df['review_lower'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop_words)])) # remove stopwords
  review_df['review_stem'] = review_df['review_without_stopwords'].apply(lambda x: " ".join([stemmer.stem(i) for i in re.sub("[^a-zA-Z]", " ", x).split() if i not in stop_words]).lower())# stemming
  voc = list(review_df['review_stem'])
  return voc
  #print(review_df)

# %%
pip install -U textblob
# Out:
# Requirement already satisfied: textblob in c:\programdata\anaconda3\lib\site-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in c:\programdata\anaconda3\lib\site-packages (from textblob) (3.6.1)
# Requirement already satisfied: joblib in c:\programdata\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (1.0.1)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (4.59.0)
# Requirement already satisfied: regex in c:\programdata\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (2021.4.4)
# Requirement already satisfied: click in c:\programdata\anaconda3\lib\site-packages (from nltk>=3.1->textblob) (7.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# pos tagging, adding feature
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\tharo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\tharo\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
from textblob import TextBlob
def pos(review_without_stopwords):
    return TextBlob(review_without_stopwords).tags

# %%
from textblob import TextBlob
def pos(review_without_stopwords):
    return TextBlob(review_without_stopwords).tags
review_df['review_pos'] = review_df.reviewLemmatized.apply(pos)
review_df['pos'] = review_df['review_pos'].map(lambda x:" ".join(["/".join(x) for x in x ]) )
review_df.head()
# Out:
#                                product  \
# 0  New Apple iPhone 11 (64GB) - Purple
# 1  New Apple iPhone 11 (64GB) - Purple
# 2  New Apple iPhone 11 (64GB) - Purple
# 3  New Apple iPhone 11 (64GB) - Purple
# 4  New Apple iPhone 11 (64GB) - Purple
#
#                                          description  \
# 0    The phone seems to be owned by some shivang ...
# 1    Its my first iphone and now I’m feeling like...
# 2    I found this black spot while doing set up. ...
# 3          Samsung s10 is much better than iphone 11
# 4    hiI had purchased this phone in first week o...
#
#                                    review_remove_num  \
# 0    The phone seems to be owned by some shivang ...
# 1    Its my first iphone and now I’m feeling like...
# 2    I found this black spot while doing set up. ...
# 3              Samsung s is much better than iphone
# 4    hiI had purchased this phone in first week o...
#
#                                         review_lower  number of stop words  \
# 0    the phone seems to be owned by some shivang ...                   162
# 1    its my first iphone and now i’m feeling like...                    36
# 2    i found this black spot while doing set up. ...                    46
# 3          samsung s10 is much better than iphone 11                    13
# 4    hii had purchased this phone in first week o...                   177
#
#                             review_without_stopwords  \
# 0  phone seems owned shivang gupta earlier...he d...
# 1  first iphone i’m feeling like i’ve wasted mone...
# 2  found black spot set up. given defective piece...
# 3                  samsung s10 much better iphone 11
# 4  hii purchased phone first week june 2020 trust...
#
#                                          review_stem  \
# 0  phone seem own shivang gupta earlier detail fi...
# 1     first iphon feel like wast money coz heat issu
# 2  found black spot set given defect piec abl giv...
# 3                          samsung much better iphon
# 4  hii purchas phone first week june trust amazon...
#
#                                     reviewLemmatized  \
# 0  phone seems owned shivang gupta earlierhe deta...
# 1  first iphone i’m feeling like i’ve wasted mone...
# 2  found black spot set up given defective piece ...
# 3                  samsung s10 much better iphone 11
# 4  hii purchased phone first week june 2020 trust...
#
#                                           review_pos  \
# 0  [(phone, NN), (seems, VBZ), (owned, VBN), (shi...
# 1  [(first, RB), (iphone, NN), (i, NN), (’, VBP),...
# 2  [(found, VBN), (black, JJ), (spot, NN), (set, ...
# 3  [(samsung, NN), (s10, NN), (much, RB), (better...
# 4  [(hii, NN), (purchased, VBD), (phone, NN), (fi...
#
#                                                  pos
# 0  phone/NN seems/VBZ owned/VBN shivang/NNS gupta...
# 1  first/RB iphone/NN i/NN ’/VBP m/RB feeling/VBG...
# 2  found/VBN black/JJ spot/NN set/VBN up/RP given...
# 3  samsung/NN s10/NN much/RB better/JJR iphone/NN...
# 4  hii/NN purchased/VBD phone/NN first/JJ week/NN...

# %%
# review_df['description'] = review_df.review_lower.apply(pos)
# review_df
#review_df.to_csv(r'D:\Information System\ADM\Project\ReviewFile.csv', encoding='utf-8', index=False)

# %%
from textblob import TextBlob
# function to calculate subjectivity
def getSubjectivity(review):
    return TextBlob(review).sentiment.subjectivity
    # function to calculate polarity
def getPolarity(review):
    return TextBlob(review).sentiment.polarity

# function to analyze the reviews
def analysis(score):
    if score < 0:
        return 'Negative'
    elif score == 0:
        return 'Neutral'
    else:
        return 'Positive'

# %%
blob_data = pd.DataFrame(review_df[['product','description', 'reviewLemmatized','pos','review_stem','review_pos']])

# %%
blob_data['Polarity'] = blob_data['reviewLemmatized'].apply(getPolarity) 
blob_data['Analysis'] = blob_data['Polarity'].apply(analysis)
blob_data.head()
# Out:
#                                product  \
# 0  New Apple iPhone 11 (64GB) - Purple
# 1  New Apple iPhone 11 (64GB) - Purple
# 2  New Apple iPhone 11 (64GB) - Purple
# 3  New Apple iPhone 11 (64GB) - Purple
# 4  New Apple iPhone 11 (64GB) - Purple
#
#                                          description  \
# 0    The phone seems to be owned by some shivang ...
# 1    Its my first iphone and now I’m feeling like...
# 2    I found this black spot while doing set up. ...
# 3          Samsung s10 is much better than iphone 11
# 4    hiI had purchased this phone in first week o...
#
#                                     reviewLemmatized  \
# 0  phone seems owned shivang gupta earlierhe deta...
# 1  first iphone i’m feeling like i’ve wasted mone...
# 2  found black spot set up given defective piece ...
# 3                  samsung s10 much better iphone 11
# 4  hii purchased phone first week june 2020 trust...
#
#                                                  pos  \
# 0  phone/NN seems/VBZ owned/VBN shivang/NNS gupta...
# 1  first/RB iphone/NN i/NN ’/VBP m/RB feeling/VBG...
# 2  found/VBN black/JJ spot/NN set/VBN up/RP given...
# 3  samsung/NN s10/NN much/RB better/JJR iphone/NN...
# 4  hii/NN purchased/VBD phone/NN first/JJ week/NN...
#
#                                          review_stem  \
# 0  phone seem own shivang gupta earlier detail fi...
# 1     first iphon feel like wast money coz heat issu
# 2  found black spot set given defect piec abl giv...
# 3                          samsung much better iphon
# 4  hii purchas phone first week june trust amazon...
#
#                                           review_pos  Polarity  Analysis
# 0  [(phone, NN), (seems, VBZ), (owned, VBN), (shi...  0.016667  Positive
# 1  [(first, RB), (iphone, NN), (i, NN), (’, VBP),...  0.025000  Positive
# 2  [(found, VBN), (black, JJ), (spot, NN), (set, ...  0.111111  Positive
# 3  [(samsung, NN), (s10, NN), (much, RB), (better...  0.500000  Positive
# 4  [(hii, NN), (purchased, VBD), (phone, NN), (fi...  0.044444  Positive

# %%
blob_data['Analysis'].value_counts()
# Out:
# Positive    14846
# Neutral      3148
# Negative     1690
# Name: Analysis, dtype: int64

# %%
positive = df[blob_data['Analysis'] == 'Positive']
negative = df[blob_data['Analysis'] == 'Negative']

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
text = " ".join(review for review in positive.description)
## good and great removed because they were included in negative sentiment
word_cloud = WordCloud(collocations = False, background_color = 'white').generate(text)
plt.imshow(word_cloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
text = " ".join(review for review in negative.description)
## good and great removed because they were included in negative sentiment
word_cloud = WordCloud(collocations = False, background_color = 'white').generate(text)
plt.imshow(word_cloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
blob_data['product'].unique()
# Out:
# array(['New Apple iPhone 11 (64GB) - Purple',
#        'Apple iPhone 7 (32GB) - Gold', 'Apple iPhone 12 (128GB) - Black',
#        'Apple iPhone\xa07 (32GB) - Rose Gold',
#        'Apple iPhone 11 (128GB) - White',
#        'New Apple iPhone 12 (64GB) - Green',
#        'New Apple iPhone 11 (64GB) - Black',
#        'Apple iPhone 11 Pro (64GB) - Gold',
#        'New Apple iPhone 11 (64GB) - White',
#        'New Apple iPhone 12 Pro (128GB) - Graphite',
#        'New Apple iPhone 11 (128GB) - Purple',
#        'New Apple iPhone 11 (128GB) - Green',
#        'New Apple iPhone 11 (128GB) - Black',
#        'New Apple iPhone 12 (128GB) - Blue',
#        'Apple iPhone 11 Pro (64GB) - Space Grey',
#        'New Apple iPhone 12 Pro Max (256GB) - Pacific Blue',
#        'New Apple iPhone 11 (128GB) - (Product) RED',
#        'Apple iPhone 11 Pro Max (64GB) - Space Grey',
#        'New Apple iPhone 12 (64GB) - (Product) RED',
#        'Apple iPhone 11 (64GB) - (Product) RED',
#        'New Apple iPhone 12 Mini (64GB) - Green',
#        'New Apple iPhone 11 (64GB) - Green',
#        'New Apple iPhone 12 (64GB) - Black',
#        'New Apple iPhone 12 Pro (256GB) - Gold',
#        'Apple iPhone 11 Pro (512GB) - Midnight Green',
#        'New Apple iPhone 12 Pro (256GB) - Pacific Blue',
#        'Apple iPhone 12 (64GB) - Blue', 'Apple iPhone 7 (32GB) - Black'],
#       dtype=object)

# %%
blob_data.to_csv(r'D:\Information System\ADM\Project\ReviewFile.csv', encoding='utf-8', index=False)

# %%
snow_data = pd.DataFrame(blob_data[['product','description', 'Analysis']])
snow_data.columns = map(lambda x: str(x).upper(), snow_data.columns)

# %%
import snowflake.connector as snow
from snowflake.connector.pandas_tools import write_pandas
from snowflake.sqlalchemy import URL
from sqlalchemy import create_engine
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\snowflake\connector\options.py:94: UserWarning: You have an incompatible version of 'pyarrow' installed (6.0.1), please install a version that adheres to: 'pyarrow<5.1.0,>=5.0.0; extra == "pandas"'
#   warn_incompatible_dep(

# %%
conn = create_engine(URL(user="lbalaji071",
   password="**********",
   account="lq34713.us-east-2.aws",
    warehouse="COMPUTE_WH",
    database="ADM_PROJECT",
    schema="public",
    role="SYSADMIN"))

# %%
connection = conn.connect()

# %%
snow_data.to_sql('sentimentanalysis', con=conn, index=False,chunksize=16000,if_exists='replace')
connection.close()
conn.dispose()
